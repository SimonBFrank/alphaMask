# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %matplotlib inline

# %%
img = np.load('data/processed/images/maksssksksss0.npy', allow_pickle=True)
targets = np.load('data/processed/annotations/maksssksksss0.npy', allow_pickle=True)

# %%
color_dict = {0:'r', 1:'orange', 2:'g'}

# %%
for i in range(len(targets)):
    plt.gca().add_patch(Rectangle(*targets[i][0] ,linewidth=2,edgecolor=color_dict[targets[i][1]],facecolor='none'))
plt.imshow(img)
plt.show()
