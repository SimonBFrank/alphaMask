# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
h, w = [], []
for f in os.listdir('data/images/training/'):
    filename = 'data/images/training/' + f
    img = plt.imread(filename)
    h.append(img.shape[0])
    w.append(img.shape[1])

# %%
h = np.array(h)
w = np.array(w)

# %%
print(np.mean(h))
print(np.median(h))
# Out:
# 881.2741296643736
# 1024.0

# %%
sns.violinplot(h)
plt.show()
# Out:
# C:\Users\frank\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(np.mean(w))
print(np.median(w))
# Out:
# 895.6931415468001
# 1024.0

# %%
sns.violinplot(w)
plt.show()
# Out:
# C:\Users\frank\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
